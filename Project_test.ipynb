# %%
class Restaurant:

    def __init__(self):
        self.food={}
        self.food_id={}
        self.admin_details={}
        self.user_details={}
        self.ordered_item={}
        

    def fun(self):
         while True:
            print("---x "*9+ " HOME PAGE " +"---x "*9+"\n")
            print("\nPlease select below option by pressing number only :)\n")
            print("\nIf you don't have an account? First register your self :)\n")
            print("\t1. ADMIN REGISTERATION   \t2. USER REGISTERATION\n  \t3. ADMIN LOGIN    \t        4. USER LOGIN\n")
            a=input("Choose one option from below : ")

            if a=="1":
                taj.admin_register()
            elif a=="2":
                taj.user_register()
            elif a=="3":
                taj.admin_login()
            elif a=="4":
                taj.user_login()           
            else:
                print("NOT A VALID OPTION")

    def admin_register(self):
        try:
            self.admin_email=input("Enter your email id : ")
            self.admin_pass=input("Enter your password : ")
            self.admin_details={"Email ID":self.admin_email,"Password":self.admin_pass}
            print("\n!! ACCOUNT CREATED SUCCESSFULLY !!\n")         
            print("ADMIN DETAILS: ")
            for i in self.admin_details:
                print(i, ":", self.admin_details[i])
        except Exception as e:
            print("\n!! PLEASE PROVIDE CORRECT INPUTS !!\n ")

    def admin_login(self):
        try:
            email_id = input("Enter your registered email id: " )
            password = input("Enter your password: ")
            if email_id == self.admin_email and password == self.admin_pass:
                print("\n Login successful!!")
                while True:
                    print("\nchoose one from below option ")
                    print("n\t1. add_newfood\n\t2. remove_food\n\t3. edit_food\n\t4. food_list\n\t5. back")
                    b=int(input("Choose one option from below : " ))
                    if b == 1:
                        self.add_newfood()
                    if b == 2:
                        self.remove_food()
                    if b == 3:
                        self.edit_food()
                    if b == 4:
                        self.food_list()
                    if b == 5:
                        break
                    else:
                        print("\n!! PLEASE PROVIDE CORRECT INPUTS !!\n ")
                else:
                    print("\n!!PLEASE ENTER CORRECT PASSWORD")
            else:
                print("\n!!PLEASE ENTER CORRECT EMAIL ID")
        except exception as e:
            print("\n!!PLEASE PROVIDE VALID INPUT")

    def add_newfood(self):
        name = input("Enter the food name")
        quantity = int(input("Enter the quantity : "))
        price = float(input("Enter the price: "))
        stock = int(input("Enter the stock in PCs "))
        discount = int(input("Enter discount value"))
        item = {"Name": name, "Quantity": quantity, "Price": price, "Stock": stock, "Discount": discount}
        self.food_id=len(self.food)+1
        self.food[self.food_id] = item
        print("Item added successfully \n", self.food)

    def remove_food(self):
        print("Surely you want to delete item")
        del self.food[int(input("Enter the food id you want to delete:"))]
        print("Item is added successfully")
        print("Remaining food items are ",self.food)

    def edit_food(self):
        try:
            c = int(input("Enter the food id you want to update "))
            for c in self.food.keys():
                print("\t1. To update name\n\t2. To update quantity\n\t3. To update price\n\t4. To update stock\n\t5. To update discount ")
                d = int(input("Please select number "))
                if d == 1:
                    self.food[c]["Name"]= input("Update food name")
                    print("Food name successfully updated")
                elif d == 2:
                    self.food[c]["Quantity"]= input("Update food quantity")
                    print("Food quantity successfully updated")
                elif d == 3:
                    self.food[c]["Price"]= input("Update food price")
                    print("Food price successfully updated")
                elif d == 4:
                    self.food[c]["Stock"]= input("Update food stock")
                    print("Food stock successfully updated")
                elif d == 5:
                    self.food[c]["Discount"]= input("Update food discount")
                    print("Food discount successfully updated")
                else:
                    print("\n!! Invalid option !!")
            else:
                print("\n!!Please enter only key of food items !!")
        except Exception as e:
            print("\n!!You entered invalid input !!")
        

    def food_list(self):
        print("\nList of all food items are : \n")
        if len(self.food)!=0:
            for i in self.food:
                print("\nfood_id : ",i," ")
                for j in self.food[i]:
                    print(j," : ",self.food[i][j])
        else:
            print("\n No food items available\n")

    def user_register(self):
        self.user_name = input("Enter your name ")
        self.user_mobile = input("Enter your mobile number ")
        self.user_address = input("Enter your address ")
        self.user_email = input("Enter your email ")
        self.user_pass = input("Enter your password ")
        self.user_details = {"Name": self.user_name, "Mobile": self.user_mobile, "Address": self.user_address, "user email_id " : self.user_email, "user password " : self.user_pass}
        print("Congratulations your account is created successfully\n ")
        print("self.user_details ")


    def user_login(self):
        try:
            user_id = input("Enter your email id ")
            user_password = input("Enter your passward ")
            if user_id == self.user_email and user_password == self.user_pass:
                    print("Congratulation you have sucessfully login")
                    while True:                                         
                        print("---x "*9+ " USER PAGE " +"---x "*9+"\n")
                        print("\nPlease select below option by pressing number only :\n")
                        print("\t1. PLACE NEW ORDER \n\t2. ORDER HISTORY\n\t3. UPDATE USER PROFILE\n\t4. HOME PAGE\n ")
                        y=input()
                        if y=="1":
                            self.place_order()
                        elif y=="2":
                            self.order_history()
                        elif y=="3":
                            self.edit_user_details()
                        elif y=="4":
                            break           
                        else:
                            print("NOT A VALID OPTION")
                    else:
                        print("Incorrect details")
            else:
                print("Incorrect details")
        except Exception as e:
            print("\n!!PLEASE PROVIDE VALID INPUT")
            
            
            
    def edit_user_details(self):
        try:
            l = int(input("Enter the food id you want to update "))
            for l in self.user_details():
                print("\t1. To update name\n\t2. To update mobile\n\t3. To update address\n\t4. To update email\n\t5. To update password ")
                m = int(input("Please select number "))
                if m == 1:
                    self.user_details[l]["Name"]= input("Enter new name")
                    print("\nUser new name successfully updated\n")
                elif m == 2:
                    self.user_details[l]["mobile"]= input("Enter new mobile number")
                    print("\nNew mobile number successfully updated\n")
                elif m == 3:
                    self.user_details[l]["address"]= input("Enter new address")
                    print("\nNew address successfully updated\n")
                elif m == 4:
                    self.user_details[l]["email"]= input("Enter new email id")
                    print("\nNew email id successfully updated\n")
                elif m == 5:
                    self.user_details[l]["pass"]= input("Enter new password")
                    print("\nNew password successfully updated\n")
                else:
                    print("\n!! Invalid option !!\n")
            else:
                print("\n!!Please enter only valid key of user details !!\n")
        except Exception as e:
            print("\n!!You entered invalid input !!\n")

    def order_history(self):
        if len(self.ordered_item)!=0:
            for i in self.ordered_item:
                print("\nYour list of previous ordered food items are")
        else:
            print("There is no Oredered history available ")          

           
    def place_order(self):
        try:
            if len(self.food)!=0:
                print("LIST OF AVAILABLE FOOD ITEMS :\n")
                menu=[]
                for items in self.food:
                    menu.append([self.food[items]["Name"], self.food[items]["Quantity"],self.food[items]["Price"]]) 
                for i in range(len(menu)):
                    print(i+1,".",menu[i])
                while True:
                    print("\n\t1. CONTINUE ORDER\n\t2. GO BACK\n")
                    x=input()
                    if x=="1":
                        print("Enter the Food number You want to ordered separated by comma")
                        y=input().split(",")
                        for i in y:                        #
                            z=int(i)
                            if z<=len(menu):
                                self.ordered_item.append(menu[z-1])
                            else:
                                print("\nFOOD ITEM NOT AVAILABLE  : ",z)
                        print("\nLIST OF FOOD ITEMS SELECTED : \n")
                        for j in self.ordered_item:
                            print(j)
                    elif x=="2":
                        break
                    else:
                        print("!! NOT A VALID OPTION !!\n")
            else:
                print("\n!! FOOD ITEMS ARE NOT AVAILABLE !!\n")      
        except Exception as e:
            print("\n!! PLEASE PROVIDE CORRECT INPUT !!")     
                   
            
        
taj = Restaurant() 
taj.fun()
# Out:
# ---x ---x ---x ---x ---x ---x ---x ---x ---x  HOME PAGE ---x ---x ---x ---x ---x ---x ---x ---x ---x
#
#
# Please select below option by pressing number only :)
#
#
# If you don't have an account? First register your self :)
#
# 	1. ADMIN REGISTERATION   	2. USER REGISTERATION
#   	3. ADMIN LOGIN    	        4. USER LOGIN
